# %% [markdown]
# The purpose of this notebook is to generate plots for the required variance in methane forcing to achieve a given variance in the observed methane time series.

# %%
from methane_noise_forcing import (
    closed_form,
    average_to_resolution,
    calculate_mean_and_ci,
)
from hydra import compose, initialize
import matplotlib as mpl
import matplotlib.pyplot as plt
from matplotlib.colors import BoundaryNorm, ListedColormap
from matplotlib.gridspec import GridSpec
from pathlib import Path
import pandas as pd
import xarray as xr
import numpy as np
from methane_noise_forcing.core import FirnFilter
import matplotlib.colors as mcolors
import matplotlib.ticker as mticker
from methane_noise_forcing.plotting.constants import (
    matplotlib_rcparams,
    fig_width_options,
    colors_vibrant,
    colors_discrete,
)
from methane_noise_forcing.noise import simulate_two_timescale_ar1
from scipy.stats import gaussian_kde


large_font = 9
matplotlib_rcparams["font.size"] = large_font
matplotlib_rcparams["axes.titlesize"] = large_font
matplotlib_rcparams["axes.labelsize"] = large_font
matplotlib_rcparams["xtick.labelsize"] = 8.5
matplotlib_rcparams["ytick.labelsize"] = 8.5
plt.rcParams.update(matplotlib_rcparams)

# %%
## figure settings
fig_width = fig_width_options["one_column"]

# %%
with initialize(
    version_base=None, config_path="../../configs"
):  # configs with data paths
    cfg = compose(
        config_name="config",
        overrides=[
            "+noise=white_noise_ar1",
            "++noise.duration_timeseries=4750",
            "+firn_kernel=firn_model_wais",
        ],
    )

# %%
## global parameters
variance_filtered_methane = 100  # ppb^2
taus_methane = np.arange(7, 13.2, 0.2)  # years

# parameters for sweeping forcing timescale
a, b = -2, 3  # log10 years
m = 10  # samples per decade
num = (b - a) * m + 1  # number of samples
taus_forcing = np.logspace(a, b, num)  # years

# lags to calculate
n_lag_years = 80  # number of year lags to calculate

# %%
## plotting functions
def plot_da_heat(
    da,
    *,
    ax=None,  # main plotting axes
    cbar_ax=None,  # optional separate axes for the colorbar
    cmap="Reds",
    log_color=False,  # True => LogNorm for both image & colorbar
    vmin=None,
    vmax=None,
    cbar_label=None,
    cbar_orientation="vertical",  # 'vertical' or 'horizontal'
    tight=False,
    **kwargs,
):
    """
    da: xarray.DataArray with dims ('taus_methane', 'taus_forcing')
    Returns: (h, ax, cbar)
    """
    if ax is None:
        ax = plt.gca()

    # Norm controls both the image mapping and the colorbar scale
    norm = mcolors.LogNorm(vmin=vmin, vmax=vmax) if log_color else None

    # Build kwargs for xarray's plot
    plot_kwargs = dict(
        x="taus_forcing",
        y="taus_methane",
        ax=ax,
        cmap=cmap,
        norm=norm,
        add_colorbar=True,
    )
    if cbar_ax is not None:
        plot_kwargs["cbar_ax"] = cbar_ax
    # Only pass cbar_kwargs if we actually set something, to avoid overriding defaults
    cbar_kwargs = {}
    if cbar_label is not None:
        cbar_kwargs["label"] = cbar_label
    if cbar_orientation != "vertical":
        cbar_kwargs["orientation"] = cbar_orientation
    if cbar_kwargs:
        plot_kwargs["cbar_kwargs"] = cbar_kwargs

    plot_kwargs.update(kwargs)
    h = da.plot(**plot_kwargs)

    # Axes formatting
    ax.set_xscale("log")
    ax.set_xlabel("Forcing timescale (yr)")
    ax.set_ylabel("Methane lifetime (yr)")
    ax.set_title("")

    # Decimal tick labels on a log x-axis (0.01, 0.1, 1, 10, ...)
    ax.xaxis.set_major_locator(mticker.LogLocator(base=10))
    ax.xaxis.set_major_formatter(mticker.FuncFormatter(lambda v, pos: f"{v:g}"))
    ax.xaxis.set_minor_formatter(mticker.NullFormatter())

    if tight:
        plt.tight_layout()

    # Grab the colorbar (xarray attaches it to the artist)
    cbar = h.colorbar
    return h, ax, cbar


def colorbar_decade_labels(cbar):
    vmin, vmax = cbar.norm.vmin, cbar.norm.vmax
    lo = int(np.ceil(np.log10(vmin)))
    hi = int(np.floor(np.log10(vmax)))
    ticks = [10**e for e in range(lo, hi + 1)]
    if ticks:  # only set if we actually have full decades in-range
        cbar.set_ticks(ticks)
    cbar.formatter = mticker.FuncFormatter(lambda v, pos: f"{v:g}")  # 1, 10, 100...
    cbar.update_ticks()

# %% [markdown]
# # generate and visualize kernel self-overlap (autocorrelation)

# %%
firn_filter = FirnFilter.fit_from_config(
    kernel_type=cfg.firn_kernel.type,
    parameters=cfg.firn_kernel.parameters,
    path_root=cfg.paths.firn_filters_root,
)
# firn_filter = FirnFilter.fit_gamma(
#     mode=30,
#     fwhm=27,
#     skew=0.7,
#     t_max=200,
#     dt=0.1,
#     taper_fraction=0
# )

dt = firn_filter.dt  # years
lags = np.arange(0, n_lag_years / dt, 1)  # years

# normalize kernel by ensuring unit area
# since series dt is equal to kernel dt, we can use the sum of the kernel directly
kernel_normalized = firn_filter.kernel / np.sum(firn_filter.kernel)

# calculate self-overlap
c_taus = closed_form.calculate_kernel_self_lag(
    kernel=kernel_normalized,
    lags=lags,
)

# plot
fig, axs = plt.subplots(1, 2, figsize=(10, 4))

# plot firn filter
time = np.arange(0, kernel_normalized.shape[0] * dt, dt)
axs[0].plot(time, kernel_normalized)
axs[0].set_xlabel("Time (years)")
axs[0].set_ylabel("Kernel (unitless)")

# plot self-overlap
axs[1].plot(lags * dt, c_taus)
axs[1].set_xlabel("Lag (years)")
axs[1].set_ylabel("Self-overlap (unitless)")

plt.tight_layout()

# %% [markdown]
# # two-timescale noise

# %% [markdown]
# ## generate autocorrelations for range of timescales

# %%
## iterate over methane lifetimes and forcing timescales to calculate autocorrelation over all lags
#  dimensions of output DataSet: (taus_methane, taus_forcing, lags)
autocorrelation_two_timescale = xr.DataArray(
    np.zeros((len(taus_methane), len(taus_forcing), len(lags))),
    dims=["taus_methane", "taus_forcing", "lags"],
    coords={
        "taus_methane": taus_methane,
        "taus_forcing": taus_forcing,
        "lags": lags,
    },
)
for tau_methane in taus_methane:
    for tau_forcing in taus_forcing:
        autocorrelation = closed_form.calculate_two_timescale_autocorrelation(
            phi_0=np.exp(-dt / tau_methane),
            phi_1=np.exp(-dt / tau_forcing),
            lags=lags,
        )
        autocorrelation_two_timescale.loc[
            dict(
                taus_methane=tau_methane,
                taus_forcing=tau_forcing,
            )
        ] = autocorrelation

# %%
## plot autocorrelations at specific lags
lag_years = 3  # years
da_to_plot = autocorrelation_two_timescale.sel(lags=lag_years)

fig = plt.figure(figsize=(6, 5))
gs = fig.add_gridspec(ncols=2, nrows=1, width_ratios=[20, 1], wspace=0.05)
ax = fig.add_subplot(gs[0, 0])
cax = fig.add_subplot(gs[0, 1])

h, ax, cbar = plot_da_heat(
    da_to_plot,
    ax=ax,
    cbar_ax=cax,
)
h.set_clim(0.3, 1)
h.set_label("something")
ax.set_title(f"Autocorrelation at {lag_years} years lag")
cbar = h.colorbar
cbar.set_label("Autocorrelation")

# %% [markdown]
# ## calculate variance required in atmospheric methane and forcing

# %%
## iterate over methane lifetimes and forcing timescales to calculate atmospheric methane and forcing variances
#  dimensions of output DataSet: (taus_methane, taus_forcing)
atmospheric_methane_variance = xr.DataArray(
    np.zeros((len(taus_methane), len(taus_forcing))),
    dims=["taus_methane", "taus_forcing"],
    coords={
        "taus_methane": taus_methane,
        "taus_forcing": taus_forcing,
    },
)
forcing_variance = xr.DataArray(
    np.zeros((len(taus_methane), len(taus_forcing))),
    dims=["taus_methane", "taus_forcing"],
    coords={
        "taus_methane": taus_methane,
        "taus_forcing": taus_forcing,
    },
)
for tau_methane in taus_methane:
    for tau_forcing in taus_forcing:
        variance_ratio_filtered_to_atmospheric = (
            closed_form.calculate_variance_ratio_filtered_to_instantaneous(
                c_taus=c_taus,
                instantaneous_autocorrelations=autocorrelation_two_timescale.loc[
                    dict(
                        taus_methane=tau_methane,
                        taus_forcing=tau_forcing,
                    )
                ],
            )
        )
        variance_atmospheric_methane = (
            variance_filtered_methane / variance_ratio_filtered_to_atmospheric
        )
        atmospheric_methane_variance.loc[
            dict(
                taus_methane=tau_methane,
                taus_forcing=tau_forcing,
            )
        ] = variance_atmospheric_methane

        variance_ratio_methane_to_forcing = (
            closed_form.calculate_two_timescale_variance_ratio_methane_to_ar1_forcing(
                tau_methane=tau_methane,
                tau_forcing=tau_forcing,
            )
        )
        variance_forcing = (
            variance_atmospheric_methane / variance_ratio_methane_to_forcing
        )
        forcing_variance.loc[
            dict(
                taus_methane=tau_methane,
                taus_forcing=tau_forcing,
            )
        ] = variance_forcing

# convert units of variance from ppb^2/yr^2 to Tg^2/yr^2
# 1 ppb = 2.75 Tg of methane
conversion_factor = 2.75
variance_forcing *= conversion_factor**2

# %%
## plot atmospheric methane variance required for a given filtered variance
fig = plt.figure(figsize=(6, 5))
gs = fig.add_gridspec(ncols=2, nrows=1, width_ratios=[20, 1], wspace=0.05)
ax = fig.add_subplot(gs[0, 0])
cax = fig.add_subplot(gs[0, 1])

h, ax, cbar = plot_da_heat(
    atmospheric_methane_variance,
    ax=ax,
    cbar_ax=cax,
    cmap="viridis",
)
cbar = h.colorbar
cbar.set_label("Atmospheric methane variance (ppb$^2$)")
h.set_clim(100, 230)

# %%
## plot forcing variance required
fig = plt.figure(figsize=(6, 5))
gs = fig.add_gridspec(ncols=2, nrows=1, width_ratios=[20, 1], wspace=0.05)
ax = fig.add_subplot(gs[0, 0])
cax = fig.add_subplot(gs[0, 1])

h, ax, cbar = plot_da_heat(
    forcing_variance,
    ax=ax,
    cbar_ax=cax,
    cmap="viridis",
    log_color=True,
)
cbar = h.colorbar
cbar.set_label("Forcing variance (Tg$^2$ yr$^{-2}$)")
colorbar_decade_labels(cbar)

# %% [markdown]
# # compare growth rate to modern methane

# %%
data_dir = Path(cfg.paths.observations_cultivated)
obs_modern = pd.read_csv(data_dir / "ch4_growth_modern_detrended.csv")
# absolute value of growth rate
obs_modern["ch4_growth_detrended_abs"] = np.abs(obs_modern["ch4_growth_detrended"])

# %%
def simulate_multiple_realizations(
    taus_forcing, var_C_target, tau_C, n_years, dt, n_ensemble
):
    """
    Simulate multiple realizations of methane time series on a grid of
    methane lifetimes (tau_C) x forcing timescales (taus_forcing).

    Parameters
    ----------
    taus_forcing : sequence of float
        Forcing timescales (years), length F.
    var_C_target : float, 1-D array (F,), 2-D array (C,F), or xarray DataArray
        Target methane variance(s) (ppb^2).
        - scalar -> broadcast to (C,F)
        - shape (F,) -> broadcast across tau_C -> (C,F)
        - shape (C,F) -> used as-is
        - if DataArray with dims ('taus_methane','taus_forcing') and/or ('taus_forcing',),
          will be aligned and converted to (C,F) in the order of (tau_C, taus_forcing).
    tau_C : float or sequence of float
        Methane lifetime(s), length C.
    n_years : float
        Total simulation length (years).
    dt : float
        Timestep (years).
    n_ensemble : int
        Number of ensemble members.

    Returns
    -------
    xr.Dataset with dims ('taus_methane','taus_forcing','ensemble','time')
        Variables: 'ch4' and 'forcing'
    """
    # --- normalize axes
    taus_forcing = np.asarray(taus_forcing, dtype=float)
    if not isinstance(tau_C, (list, np.ndarray)):
        tau_C = [tau_C]
    tau_C = np.asarray(tau_C, dtype=float)

    C = tau_C.size
    F = taus_forcing.size

    # --- build time axis
    n_steps = int(np.round(n_years / dt))
    time = np.arange(n_steps) * dt
    ensemble = np.arange(n_ensemble)

    # --- normalize var_C_target to (C, F)
    var_grid = None

    # If xarray DataArray, try to align by coord names
    try:
        import xarray as xr  # in case this function is used standalone

        if isinstance(var_C_target, xr.DataArray):
            da = var_C_target
            # If it has taus dims, reindex/select in provided order; else try to interpret 1-D along forcing
            if "taus_methane" in da.dims and "taus_forcing" in da.dims:
                da = da.sel(
                    taus_methane=xr.DataArray(tau_C, dims="taus_methane"),
                    taus_forcing=xr.DataArray(taus_forcing, dims="taus_forcing"),
                    method="nearest",
                )
                var_grid = da.transpose("taus_methane", "taus_forcing").values
            elif "taus_forcing" in da.dims and da.ndim == 1:
                da = da.sel(
                    taus_forcing=xr.DataArray(taus_forcing, dims="taus_forcing"),
                    method="nearest",
                )
                var_grid = np.broadcast_to(da.values, (C, F))
            else:
                # Fall back to numpy handling below
                pass
    except Exception:
        pass

    if var_grid is None:
        arr = np.asarray(var_C_target, dtype=float)
        if arr.ndim == 0:
            var_grid = np.full((C, F), float(arr))
        elif arr.ndim == 1:
            if arr.shape[0] != F:
                raise ValueError(
                    f"1-D var_C_target must have length {F} (taus_forcing), got {arr.shape[0]}."
                )
            var_grid = np.broadcast_to(arr[None, :], (C, F))
        elif arr.ndim == 2:
            if arr.shape != (C, F):
                raise ValueError(
                    f"2-D var_C_target must have shape {(C, F)} "
                    f"(len(tau_C), len(taus_forcing)), got {arr.shape}."
                )
            var_grid = arr
        else:
            raise ValueError(
                "var_C_target must be scalar, 1-D, 2-D, or an xarray.DataArray with proper dims."
            )

    # --- simulate
    methane_blocks = []
    for i, tau_methane in enumerate(tau_C):
        forcing_blocks = []
        for j, tau_eta in enumerate(taus_forcing):
            var_C = float(var_grid[i, j])

            x_ens, eta_ens = simulate_two_timescale_ar1(
                tau_x=tau_methane,
                tau_eta=tau_eta,
                variance_x=var_C,
                n_steps=n_steps,
                dt=dt,
                n_ens=n_ensemble,
            )

            ds = xr.Dataset(
                {
                    "ch4": (("ensemble", "time"), x_ens),
                    "forcing": (("ensemble", "time"), eta_ens),
                },
                coords={"time": time, "ensemble": ensemble},
            ).expand_dims({"taus_forcing": [tau_eta]})

            forcing_blocks.append(ds)

        ds_for_tau = xr.concat(forcing_blocks, dim="taus_forcing")
        ds_for_tau = ds_for_tau.expand_dims({"taus_methane": [tau_methane]})
        methane_blocks.append(ds_for_tau)

    out = xr.concat(methane_blocks, dim="taus_methane").assign_coords(
        taus_methane=("taus_methane", tau_C),
        taus_forcing=("taus_forcing", taus_forcing),
    )
    return out

# %%
taus_forcing = [0.01, 0.1, 1.0, 10.0, 100.0, 1000.0]
taus_C = [8.0, 10.0, 12.0]
n_ensemble = 100
dt_small = 0.01
n_years = 1000

var_C_target = atmospheric_methane_variance.sel(
    taus_methane=taus_C,
    taus_forcing=taus_forcing,
    method="nearest",
)

two_timescale_noise = simulate_multiple_realizations(
    taus_forcing=taus_forcing,
    var_C_target=var_C_target,  # (C,F) DataArray; function will align/order
    tau_C=taus_C,
    n_years=n_years,
    dt=dt_small,
    n_ensemble=n_ensemble,
)

# %%
## average to annual resolution, then calculate growth over some lag
dt_annual = 1.0
change_interval = 1

two_timescale_noise_annual = average_to_resolution(
    two_timescale_noise, resolution=dt_annual, time_dim="time"
)

# lagged difference: x[t] - x[t-lag]
noise_change = two_timescale_noise_annual - two_timescale_noise_annual.shift(
    time=change_interval
)
# drop the leading NaNs introduced by the shift
noise_change = noise_change.isel(time=slice(change_interval, None))

noise_change_abs = np.abs(noise_change)

# validation
ch4_annual_slice = two_timescale_noise_annual.ch4.isel(
    ensemble=0, taus_methane=0, taus_forcing=0
).values
ch4_change_direct = (
    ch4_annual_slice[change_interval:] - ch4_annual_slice[:-change_interval]
)
np.allclose(
    noise_change.ch4.isel(ensemble=0, taus_methane=0, taus_forcing=0).values,
    ch4_change_direct,
)
# Out:
# True

# %% [markdown]
# # plot

# %%
## plotting functions
def annotate_panel(ax, text, loc="left", xpad=0.01, ypad=0.01, color="k", **kwargs):
    """Place bold text at the top-left/right inside an axis."""
    x = xpad if loc == "left" else 1 - xpad
    y = 1 - ypad
    ha = "left" if loc == "left" else "right"
    ax.text(
        x,
        y,
        text,
        transform=ax.transAxes,
        ha=ha,
        va="top",
        fontweight="bold",
        color=color,
        **kwargs,
    )

def compute_violin_coords(
    data,
    center,
    width,
    density_points=256,
    axis_scale="log",
    kde_kwargs=None,
    reflect_at_zero=False,
):
    """
    Compute violin plot coordinates for KDE density visualization.
    
    Parameters
    ----------
    data : array-like
        1D array of data values to visualize
    center : float
        Center position of the violin on the x-axis (e.g., timescale value)
    width : float
        Width parameter controlling violin spread:
        - For log scale: width in decades (log10 space)
        - For linear scale: absolute width in data units
    density_points : int, optional
        Number of points to sample for the violin shape
    axis_scale : {'log', 'linear'}, optional
        Type of x-axis scaling
    kde_kwargs : dict, optional
        Additional kwargs passed to gaussian_kde (e.g., bw_method)
    reflect_at_zero : bool, optional
        If True, reflect data at zero to prevent KDE from extending to negative values.
        Useful for distributions bounded at zero (like absolute values).
    
    Returns
    -------
    y : ndarray
        Y-coordinates (data values)
    x_left : ndarray
        Left x-coordinates for fill_betweenx
    x_right : ndarray
        Right x-coordinates for fill_betweenx
    """
    from scipy.stats import gaussian_kde
    
    data = np.asarray(data)
    data = data[~np.isnan(data)]
    
    if data.size == 0:
        return None, None, None
    
    # Handle reflection at zero for bounded distributions
    if reflect_at_zero:
        # Reflect negative values across zero
        data_for_kde = np.concatenate([data, -data])
    else:
        data_for_kde = data
    
    # Compute KDE
    kde_kwargs = kde_kwargs or {}
    kde = gaussian_kde(data_for_kde, **kde_kwargs)
    
    # Sample range
    dmin, dmax = np.min(data), np.max(data)
    y = np.linspace(dmin, dmax, density_points)
    
    # Evaluate KDE only at positive values
    v = kde(y)
    
    # Normalize to max = 1
    v = v / v.max()
    
    # Compute x coordinates based on scale
    if axis_scale == "log":
        # Width in decades (log10 space)
        half_width_decades = width * v
        m = 10.0 ** half_width_decades
        x_left = center / m
        x_right = center * m
    elif axis_scale == "linear":
        # Width in linear space
        half_width = width * v
        x_left = center - half_width
        x_right = center + half_width
    else:
        raise ValueError(f"axis_scale must be 'log' or 'linear', got {axis_scale}")
    
    return y, x_left, x_right

def multiplot_params(
    tau, tau_methane_mid, lw_other=0.8, alpha_other=0.7
):
    """ensures line with focus in panel b is thicker, more opaque, and on top"""
    if tau == tau_methane_mid:
        lw = 3
        alpha = 1
        zorder_val = 100
    else:
        lw = lw_other
        alpha = alpha_other
        zorder_val = 1 + 0.01 * tau
    kwargs = dict(lw=lw, alpha=alpha, zorder=zorder_val)
    return kwargs

## function for curve-following annotations
from matplotlib.textpath import TextPath
from matplotlib.patches import PathPatch
from matplotlib.font_manager import FontProperties
from matplotlib.path import Path

def text_along_curve(
    ax,
    x_data,
    y_data,
    text,
    x_start,
    fontsize=8,
    color="k",
    fontweight="normal",
    y_offset_points=0.0,   # <<--- NEW PARAMETER
    **patch_kwargs,
):
    """
    Draw `text` so that its baseline follows the curve (x_data, y_data),
    with an optional constant vertical offset expressed in points.
    """

    x_data = np.asarray(x_data)
    y_data = np.asarray(y_data)

    # --- 1. Transform curve to display coords ---
    xy_disp = ax.transData.transform(np.column_stack([x_data, y_data]))
    xd, yd = xy_disp[:, 0], xy_disp[:, 1]

    # Arc-length in display coords
    ds = np.hypot(np.diff(xd), np.diff(yd))
    s = np.concatenate([[0.0], np.cumsum(ds)])

    # Closest point in data space
    idx_start = np.argmin(np.abs(x_data - x_start))
    s_center = s[idx_start]

    # --- 2. Build text path in points ---
    fp = FontProperties(weight=fontweight)
    tp = TextPath((0, 0), text, size=fontsize, prop=fp)
    verts = tp.vertices.copy()
    codes = tp.codes

    # Points → pixels
    dpi = ax.figure.dpi
    pt_to_px = dpi / 72.0
    verts[:, 0] *= pt_to_px
    verts[:, 1] *= pt_to_px

    # Separate baseline (x-direction)
    x_min = verts[:, 0].min()
    verts[:, 0] -= x_min
    text_length = verts[:, 0].max() - verts[:, 0].min()

    # Center text baseline at s_center
    s_start = s_center - text_length / 2.0

    # --- NEW: vertical offset in display pixels ---
    y_offset_px = y_offset_points * pt_to_px

    # --- 3. Warp glyphs along curve ---
    verts_warped = np.zeros_like(verts)

    for i, (u, v) in enumerate(verts):
        s_target = s_start + u

        # Clamp
        if s_target <= 0:
            idx = 0
            t = 0.0
        elif s_target >= s[-1]:
            idx = len(s) - 2
            t = 1.0
        else:
            idx = np.searchsorted(s, s_target) - 1
            idx = np.clip(idx, 0, len(s) - 2)
            t = (s_target - s[idx]) / (s[idx + 1] - s[idx])

        # Interpolate curve point
        x_c = xd[idx] + t * (xd[idx + 1] - xd[idx])
        y_c = yd[idx] + t * (yd[idx + 1] - yd[idx])

        # Tangent
        tx = xd[idx + 1] - xd[idx]
        ty = yd[idx + 1] - yd[idx]
        nrm = np.hypot(tx, ty)
        if nrm == 0:
            tx, ty = 1.0, 0.0
            nx, ny = 0.0, 1.0
        else:
            tx /= nrm
            ty /= nrm
            nx, ny = -ty, tx  # normal vector

        # Warp vertex: baseline (u) maps to arclength, v maps normal
        x_v = x_c + v * nx
        y_v = y_c + v * ny

        # --- apply constant vertical offset in display coords ---
        y_v += y_offset_px

        verts_warped[i, 0] = x_v
        verts_warped[i, 1] = y_v

    # --- 4. Transform back to data coords ---
    inv = ax.transData.inverted()
    verts_data = inv.transform(verts_warped)

    # Build and add path patch
    text_path = Path(verts_data, codes)
    patch = PathPatch(
        text_path,
        facecolor=color,
        edgecolor="none",
        lw=0,
        **patch_kwargs,
    )
    ax.add_patch(patch)

import numpy as np

def arrow_along_curve(
    ax,
    x_data,
    y_data,
    x_start,
    length_points=40.0,
    offset_points=10.0,
    color="k",
    **arrowprops,
):
    """
    Draw an arrow roughly parallel to the curve (x_data, y_data),
    centered at x_start, with a constant offset in screen space.

    Parameters
    ----------
    ax : matplotlib.axes.Axes
    x_data, y_data : 1D arrays
        Curve in data coordinates.
    x_start : float
        Data x-location where the arrow is centered along the curve.
    length_points : float
        Arrow length in points (approx along the curve).
    offset_points : float
        Offset from the curve in points (normal to the curve).
    color : str
        Arrow color.
    arrowprops :
        Extra kwargs forwarded into ax.annotate(..., arrowprops=...).
    """
    x_data = np.asarray(x_data)
    y_data = np.asarray(y_data)

    # ---- Curve in display coords (handles log axes automatically) ----
    xy_disp = ax.transData.transform(np.column_stack([x_data, y_data]))
    xd, yd = xy_disp[:, 0], xy_disp[:, 1]

    # Arc length along the curve in display coords
    ds = np.hypot(np.diff(xd), np.diff(yd))
    s = np.concatenate([[0.0], np.cumsum(ds)])

    # Center position along curve: closest x to x_start in data space
    idx_center = np.argmin(np.abs(x_data - x_start))
    s_center = s[idx_center]

    # Convert from points to pixels
    dpi = ax.figure.dpi
    pt_to_px = dpi / 72.0
    L = length_points * pt_to_px
    d = offset_points * pt_to_px

    s_start = np.clip(s_center - L / 2.0, s[0], s[-1])
    s_end   = np.clip(s_center + L / 2.0, s[0], s[-1])

    def point_and_normal_at_s(s_target):
        """Return (x_disp, y_disp) offset by d*normal, plus tangent."""
        if s_target <= s[0]:
            i = 0
            t = 0.0
        elif s_target >= s[-1]:
            i = len(s) - 2
            t = 1.0
        else:
            i = np.searchsorted(s, s_target) - 1
            i = np.clip(i, 0, len(s) - 2)
            t = (s_target - s[i]) / (s[i + 1] - s[i])

        # Curve point
        x_c = xd[i] + t * (xd[i + 1] - xd[i])
        y_c = yd[i] + t * (yd[i + 1] - yd[i])

        # Tangent
        tx = xd[i + 1] - xd[i]
        ty = yd[i + 1] - yd[i]
        nrm = np.hypot(tx, ty)
        if nrm == 0:
            tx, ty = 1.0, 0.0
        else:
            tx /= nrm
            ty /= nrm

        # Normal (rotate tangent 90° CCW)
        nx, ny = -ty, tx

        # Offset point in display space
        x_o = x_c + d * nx
        y_o = y_c + d * ny

        return x_o, y_o, tx, ty

    # Start and end of the arrow in display coords
    x_start_disp, y_start_disp, tx0, ty0 = point_and_normal_at_s(s_start)
    x_end_disp,   y_end_disp,   tx1, ty1 = point_and_normal_at_s(s_end)

    # (Optional) make the arrow point roughly "up-left" by swapping if needed
    # You can flip direction if you want:
    # if x_end_disp > x_start_disp:
    #     x_start_disp, y_start_disp, x_end_disp, y_end_disp = \
    #         x_end_disp, y_end_disp, x_start_disp, y_start_disp

    # Back to data coords
    inv = ax.transData.inverted()
    x0, y0 = inv.transform([x_start_disp, y_start_disp])
    x1, y1 = inv.transform([x_end_disp, y_end_disp])

    # Draw arrow
    props = dict(arrowstyle="<-", color=color, linewidth=0.8)
    props.update(arrowprops)

    ax.annotate("", xy=(x1, y1), xytext=(x0, y0), arrowprops=props)

# %%
import numpy as np
from matplotlib.colors import to_rgba

LN10 = np.log(10.0)

def lognorm_sigma_log10_from_mean_std(mean, std):
    """
    Convert (mean, std) in linear space to sigma in log10-space
    for a lognormal distribution.
    """
    var = std**2
    sigma_ln = np.sqrt(np.log(var / mean**2 + 1.0))
    sigma_log10 = sigma_ln / LN10
    return sigma_log10

import numpy as np
from matplotlib.colors import to_rgba, LinearSegmentedColormap

LN10 = np.log(10.0)

def add_loglog_gaussian_blob(
    ax,
    *,
    x_mean, x_sigma_log10,
    y_mean, y_sigma_log10,
    color,
    max_alpha=0.65,
    n_grid=220,
    n_sigma=6.0,
    sigma_mult=2.2,
    taper_gamma=0.5,
    alpha_floor=1e-3,   # <- key: mask tiny tails so they don't tint the whole plot
    zorder=0.8,
):
    if x_mean <= 0 or y_mean <= 0:
        raise ValueError("Means must be > 0 for log axes.")
    if x_sigma_log10 <= 0 or y_sigma_log10 <= 0:
        raise ValueError("Sigmas must be > 0.")

    mx = np.log10(x_mean)
    my = np.log10(y_mean)

    sx = x_sigma_log10 * sigma_mult
    sy = y_sigma_log10 * sigma_mult

    x_log = np.linspace(mx - n_sigma*sx, mx + n_sigma*sx, n_grid)
    y_log = np.linspace(my - n_sigma*sy, my + n_sigma*sy, n_grid)
    XLOG, YLOG = np.meshgrid(x_log, y_log)

    # 2D Gaussian in log10 space
    dx2 = ((XLOG - mx) / sx) ** 2
    dy2 = ((YLOG - my) / sy) ** 2
    A = np.exp(-0.5 * (dx2 + dy2))

    # gentler taper (fatter blob)
    A = (A ** taper_gamma) * max_alpha

    # mask tiny alpha so mesh doesn't cover the whole plot
    A = np.ma.masked_less(A, alpha_floor)

    # to linear coords
    X = 10 ** XLOG
    Y = 10 ** YLOG

    # colormap: transparent -> colored (with alpha baked in)
    r, g, b, _ = to_rgba(color)
    cmap = LinearSegmentedColormap.from_list(
        "blob",
        [(r, g, b, 0.0), (r, g, b, max_alpha)],
        N=256,
    )
    
    levels = np.linspace(alpha_floor, max_alpha, 100)

    ax.contourf(
        X, Y, A,
        levels=levels,
        cmap=cmap,
        antialiased=True,
        zorder=zorder,
    )

# %%
## plot toggles for ax_forcing
plot_toggles = {
    "plot_text": True,               # fast-and-large / slow-and-small curve text
    "plot_oh_shading": True,         # OH gaussian blob shading
    "plot_wetlands_shading": True,   # Wetlands gaussian blob shading
    "plot_bb_shading": True,         # Biomass Burning gaussian blob shading
}

_shading_toggle_map = {
    "OH": "plot_oh_shading",
    "Wetlands": "plot_wetlands_shading",
    "Biomass Burning": "plot_bb_shading",
}

def generate_figure_name(plot_toggles, tau_methane_mid):
    """Generate a figure name based on the toggled plot options.
    
    Adds suffixes if certain plot options are NOT enabled.
    """
    if tau_methane_mid == 10.0:
        name_base = "fig_3"
    else:
        name_base = f"fig_3_tau{int(tau_methane_mid)}"
    
    for key, value in plot_toggles.items():
        if not value:
            key_clean = key.replace("plot_", "no_")
            name_base += f"-{key_clean}"
    
    return name_base

# %%
## forcing plot (sweep over methane lifetimes)
# --- Configuration ---
from cmath import tau


taus_to_plot = np.arange(7, 14)  # 7–13 yr inclusive
tau_methane_mid = 10.0  # main lifetime for panel (b)
xlim = (0.0046, 1878)
xlim_modern = (-0.44, 0.44)
xticks_modern = ([0])
ylim_atmospheric = (0.6, 3.6)
ylim_change_mapper = {
    8.0: (-0.5, 20.5),
    10.0: (-0.5, 15.5),
    12.0: (-0.5, 15.5),
}
yticks_change = (0, 2.5, 5, 7.5, 10, 12.5, 15)
ylim_forcing = (0.4, 11000)
density_points = 256
width_decades = 0.2
alpha_fill = 0.3
labelx = -0.23  # x position for y-axis labels
discrete_vals = [9, 10, 14, 15, 17, 18, 26]  # taus to highlight in colors_discrete

# --- Colors for variance source categories ---
plot_variance_colors = {
    'OH': colors_vibrant['cyan'],
    'Biomass Burning': colors_vibrant['red'],
    'Wetlands': "#F4A736" #colors_bright['purple']
}


# # --- Colormap for τ sweep ---
# # Sample color map at discrete tau values
# n_colors = len(taus_to_plot)
# cmap_continuous = plt.get_cmap("viridis")
# colors_discrete = [
#     cmap_continuous(i / (n_colors - 0.6)) for i in range(n_colors)
# ]  # -1 for full range
# cmap = ListedColormap(colors_discrete)

# # Define boundaries halfway between tau values
# boundaries = np.concatenate(
#     [
#         [taus_to_plot[0] - 0.5],  # lower bound
#         (taus_to_plot[:-1] + taus_to_plot[1:]) / 2,  # midpoints
#         [taus_to_plot[-1] + 0.5],  # upper bound
#     ]
# )
# norm = BoundaryNorm(boundaries, cmap.N)

# sm = mpl.cm.ScalarMappable(norm=norm, cmap=cmap)
# sm.set_array([])
# mid_color = cmap(taus_to_plot.tolist().index(tau_methane_mid))

# --- Figure layout ---
fig = plt.figure(figsize=(fig_width_options["one_column"], 3 * 2.3))
gs = GridSpec(
    nrows=3, ncols=3, width_ratios=[2.9, 0.1, 0.2], figure=fig, hspace=0.07, wspace=0.11
)

# -------------------------------------------------------------------
# (a) Atmospheric methane variance sweep
# -------------------------------------------------------------------
ax_atmospheric = fig.add_subplot(gs[0, 0])
# for tau in taus_to_plot:
#     da_meth = atmospheric_methane_variance.sel(
#         taus_methane=float(tau), method="nearest"
#     )
#     plot_kwargs = multiplot_params(
#         tau, tau_methane_mid=tau_methane_mid, lw_other=0.8, alpha_other=0.8
#     )
#     ax_atmospheric.plot(
#         da_meth.taus_forcing,
#         da_meth / variance_filtered_methane,
#         color=cmap(norm(tau)),
#         **plot_kwargs,
#     )
da_meth = atmospheric_methane_variance.sel(
    taus_methane=10, method="nearest"
)
ax_atmospheric.plot(
    da_meth.taus_forcing,
    da_meth / variance_filtered_methane,
    color=colors_vibrant["blue"],
    lw = 3
)

ax_atmospheric.axhline(1, color="k", linestyle="-.", alpha=0.3)
ax_atmospheric.set_xscale("log")
ax_atmospheric.set_xlim(xlim)
ax_atmospheric.set_xticklabels([])
ax_atmospheric.set_ylim(ylim_atmospheric)
ax_atmospheric.set_ylabel(
    "Ratio of atmospheric to ice core\nmethane variance"
)

# # --- Colorbar for τ sweep ---
# cax = fig.add_subplot(gs[0, 1])
# cb = fig.colorbar(
#     sm,
#     cax=cax,
#     orientation="vertical",
#     ticks=taus_to_plot,
#     boundaries=boundaries,
#     spacing="proportional",
# )
# cb.set_label("Methane lifetime" + r" $\tau_{c'}$ (year)")
# cb.minorticks_off()
# cb.ax.yaxis.set_minor_locator(mticker.NullLocator())

# -------------------------------------------------------------------
# (b) Annual methane change (violin) – τ=10
# -------------------------------------------------------------------
ax_change = fig.add_subplot(gs[1, 0])
ax_change.set_xscale("log")
ax_change.set_xlim(xlim)
ax_change.set_ylim(ylim_change_mapper[tau_methane_mid])

for timescale in taus_forcing:
    data = noise_change_abs.ch4.sel(
        taus_methane=tau_methane_mid, taus_forcing=timescale
    ).values.ravel()
    
    y, x_left, x_right = compute_violin_coords(
        data=data,
        center=timescale,
        width=width_decades,
        density_points=density_points,
        axis_scale="log",
        reflect_at_zero=True,  # Enable reflection for absolute value distributions
    )
    
    if y is None:
        continue
    
    # Clip to axis limits
    x_left = np.clip(x_left, xlim[0], xlim[1])
    x_right = np.clip(x_right, xlim[0], xlim[1])
    ax_change.fill_betweenx(
        y, x_left, x_right, facecolor=colors_vibrant["blue"], edgecolor="none", alpha=alpha_fill
    )
    mean, ci_lower, ci_upper = calculate_mean_and_ci(
        noise_change_abs.ch4.sel(taus_methane=tau_methane_mid, taus_forcing=timescale),
        dim=["ensemble", "time"],
    )
    median = noise_change_abs.ch4.sel(
        taus_methane=tau_methane_mid, taus_forcing=timescale
    ).median(dim=["ensemble", "time"])
    ax_change.errorbar(
        timescale,
        float(median),
        yerr=[[float(median - ci_lower)], [float(ci_upper - median)]],
        fmt="o",
        markersize=5,
        color=colors_vibrant["blue"],
        zorder=10,
    )

ax_change.set_ylabel(f"Annual atmospheric methane\nchange (ppb / year)")
ax_change.set_yticks(yticks_change)
ax_change.set_xticklabels([])

# -------------------------------------------------------------------
# (c) Modern violin
# -------------------------------------------------------------------
ax_modern = fig.add_subplot(gs[1, 1:])
# bin_edges = np.linspace(0, 15, 19)
data = obs_modern["ch4_growth_detrended_abs"].values

y, x_left, x_right = compute_violin_coords(
    data=data,
    center=0,
    width=width_decades,
    density_points=density_points,
    axis_scale="linear",
    reflect_at_zero=True,  # Enable reflection for absolute value distributions
)
x_left = np.clip(x_left, xlim_modern[0], xlim_modern[1])
x_right = np.clip(x_right, xlim_modern[0], xlim_modern[1])
ax_modern.fill_betweenx(
    y, x_left, x_right, facecolor='k', edgecolor="none", alpha=alpha_fill
)

median_modern = obs_modern["ch4_growth_detrended_abs"].median()
ci_lower_modern = obs_modern["ch4_growth_detrended_abs"].quantile(0.025)
ci_upper_modern = obs_modern["ch4_growth_detrended_abs"].quantile(0.975)
ax_modern.errorbar(
    0,
    float(median_modern),
    yerr=[
        [float(median_modern - ci_lower_modern)],
        [float(ci_upper_modern - median_modern)],
    ],
    fmt="o",
    markersize=5,
    color="k",
    zorder=10,
)

ax_modern.set_ylim(ylim_change_mapper[tau_methane_mid])
ax_modern.set_yticks(yticks_change)
ax_modern.set_yticklabels([])
ax_modern.tick_params(
    axis="y", which="major", direction="out", length=2.5
)
ax_modern.set_xlim(xlim_modern)
ax_modern.set_xticks(xticks_modern)
ax_modern.set_xticklabels([])
ax_modern.set_xlabel("Modern", labelpad=-1)
ax_modern.grid(False)
ax_modern.spines[['right', 'top']].set_visible(False)


# -------------------------------------------------------------------
# (d) Source/sink variance sweep
# -------------------------------------------------------------------
ax_forcing = fig.add_subplot(gs[2, 0])
# for tau in taus_to_plot:
#     da_force = forcing_variance.sel(taus_methane=float(tau), method="nearest")
#     plot_kwargs = multiplot_params(
#         tau, tau_methane_mid=tau_methane_mid, lw_other=0.8, alpha_other=0.6
#     )
#     ax_forcing.plot(
#         da_force.taus_forcing,
#         da_force,
#         color=cmap(norm(tau)),
#         **plot_kwargs,
#     )
da_force = forcing_variance.sel(taus_methane=float(10), method="nearest")
plot_kwargs = multiplot_params(
    10, tau_methane_mid=tau_methane_mid, lw_other=0.8, alpha_other=0.6
)
ax_forcing.plot(
    da_force.taus_forcing,
    da_force,
    color=colors_vibrant["blue"],
    **plot_kwargs,
)

ax_forcing.set_ylabel("Source-sink imbalance\nvariance ([Tg CH$_4$ / year]$^2$)")
ax_forcing.set_ylim(ylim_forcing)
ax_forcing.set_yscale("log")
ax_forcing.yaxis.set_major_locator(mticker.LogLocator(base=10))
ax_forcing.yaxis.set_major_formatter(mticker.FuncFormatter(lambda v, pos: f"{v:g}"))
ax_forcing.yaxis.set_minor_formatter(mticker.NullFormatter())
ax_forcing.set_xscale("log")
ax_forcing.set_xlim(xlim)
ax_forcing.set_xlabel(r"Source-sink imbalance timescale $\tau_{\varepsilon}$ (year)")
ax_forcing.xaxis.set_major_locator(mticker.LogLocator(base=10))
ax_forcing.xaxis.set_major_formatter(mticker.FuncFormatter(lambda v, pos: f"{v:g}"))
ax_forcing.xaxis.set_minor_formatter(mticker.NullFormatter())

# --- Add transparent squares for source categories ---
# Convert ln-sigma -> log10-sigma by dividing by ln(10).
categories_params = {
    "Biomass Burning": {
        "timescale_mean": 0.5,
        "timescale_std": 0.2,
        "variance_mean": 38.5633,
        "variance_sigma_ln": 0.3169,
        "color": plot_variance_colors["Biomass Burning"],
        "max_alpha": 0.95,
    },
    "Wetlands": {
        "timescale_mean": 4.0,
        "timescale_std": 2,
        "variance_mean": 30.4269,
        "variance_sigma_ln": 0.75,
        "color": plot_variance_colors["Wetlands"],
        "max_alpha": 1,
    },
    "OH": {
        "timescale_mean": 0.4,
        "timescale_std": 0.2,
        "variance_mean": 6.9969,
        "variance_sigma_ln": 0.2532,
        "color": plot_variance_colors["OH"],
        "max_alpha": 0.9,
    },
}

for name, p in categories_params.items():
    # skip shading if toggled off
    if not plot_toggles.get(_shading_toggle_map.get(name), True):
        continue

    ts_sigma_log10 = lognorm_sigma_log10_from_mean_std(
        p["timescale_mean"], p["timescale_std"]
    )
    var_sigma_log10 = p["variance_sigma_ln"] / LN10

    add_loglog_gaussian_blob(
        ax_forcing,
        x_mean=p["timescale_mean"],
        x_sigma_log10=ts_sigma_log10,
        y_mean=p["variance_mean"],
        y_sigma_log10=var_sigma_log10,
        color=p["color"],
        max_alpha=p["max_alpha"],      # center darkness
        sigma_mult=2.2,      # BIGGER overall blobs (try 1.6–2.6)
        taper_gamma=0.5,    # gentler taper (try 0.35–0.7)
        n_sigma=6.0,        # no visible edge
        n_grid=220,
        zorder=0.8,         # set > lines to be on top; set < lines to be behind
    )

# --- Add curve-following labels on top of the tau=7 curve ---
tau_label = 10.0
da_label = forcing_variance.sel(taus_methane=tau_label, method="nearest")
x_data = da_label.taus_forcing.values
y_data = da_label.values

if plot_toggles["plot_text"]:
    text_along_curve(
        ax_forcing,
        x_data,
        y_data,
        "fast-and-large",
        x_start=0.05,  
        fontsize=9,
        color='k',
        y_offset_points=4,
    )

    text_along_curve(
        ax_forcing,
        x_data,
        y_data,
        "slow-and-small",
        x_start=89,  
        fontsize=9,
        color='k',
        y_offset_points=3,
    )

# -------------------------------------------------------------------
# (e) Annotations
# -------------------------------------------------------------------
# annotate_panel(ax_atmospheric, "σ$_{c'}^2$/σ$_{ice\,core}^2$ (a)", loc="right")
# annotate_panel(
#     ax_change,
#     "|ΔC'$_{annual}$| (b)",
#     loc="right",
# )
# annotate_panel(ax_modern, "(c)", xpad=0.04, loc="left")
# annotate_panel(ax_forcing, "σ$_{ε}^2$ (d)", loc="right")
# in forcing, the different source categories
ypad_top = 0.07
ypad_dy = 0.07
xpad = 0.01
for i, (name, p) in enumerate(categories_params.items()):
    y = ypad_top + i * ypad_dy
    x = xpad
    ha = "left"
    ax_forcing.text(
        x,
        y,
        name,
        transform=ax_forcing.transAxes,
        ha=ha,
        va="top",
        fontweight="bold",
        color=p["color"],
        alpha=p["max_alpha"],
    )

for ax in [ax_atmospheric, ax_change, ax_forcing]:
    ax.yaxis.set_label_coords(labelx, 0.5)
    ax.yaxis.label.set_verticalalignment("center")

# -------------------------------------------------------------------
# Save
# -------------------------------------------------------------------
name = generate_figure_name(plot_toggles, tau_methane_mid)
fig.savefig(
    f"{cfg.paths.figures_dir}/figures_for_berkeley/{name}.png", bbox_inches="tight", dpi=300
)
